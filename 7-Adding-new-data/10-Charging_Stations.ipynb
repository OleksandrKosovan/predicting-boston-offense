# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Link
# https://data.boston.gov/dataset/charging-stations/resource/2ce19df4-7070-4e0a-b009-c92e7e2b2f11

# %%
df1 = pd.read_csv('data/Charging_Stations.csv')

# %%
df1.head()
# Out:
#            X          Y  OBJECTID Fuel_Type_Code    Station_Name  \
# 0 -71.054772  42.355398         1           ELEC  50 POST OFFICE
# 1 -71.074718  42.337886         2           ELEC       TRANSCOMM
# 2 -71.010123  42.388742         3           ELEC  CHARGE STATION
# 3 -71.101414  42.344170         4           ELEC         TRILOGY
# 4 -71.082597  42.347280         5           ELEC  PRUDENTIAL CTR
#
#           Street_Address                            Intersection_Directions  \
# 0  50 Post Office Square  STATION #3; The station is on the first level ...
# 1         2 E Concord St  710 D; 1st level of garage, east side\n710 C; ...
# 2       100 Boardman St.  HILTON3; East side of hotel\nHILTON2; East sid...
# 3      180 Brookline Ave                                   FEN RES; Welcome
# 4                   I-90          P1-RED LEVEL A; South Garage P1 Red Level
#
#      City State   ZIP         ...                       Updated_At  \
# ...

# %%
df1 = df1[['X','Y']]

# %%
df1.shape
# Out:
# (55, 2)

# %%
df1.describe()
# Out:
#                X          Y
# count  55.000000  55.000000
# mean  -71.075117  42.350512
# std     0.029698   0.010212
# min   -71.169089  42.321078
# 25%   -71.093158  42.346139
# 50%   -71.065575  42.351069
# 75%   -71.055532  42.355755
# max   -71.010123  42.388742

# %%
df = pd.read_csv('data/finish-crime-weather.csv')

# %%
df['Charging_Stations_distance_25'] = 0
df['Charging_Stations_distance_min'] = 0
df['Charging_Stations_number_near'] = 0

# %%
def distance(x1,y1,x2,y2):    
    return ((x1-x2)**2+(y1-y2)**2)**(1/2)

# %%
i = 0

while i < len(df):
    
    k = 0
    
    array = []
    
    while k < len(df1):
        
        
        array.append(
            distance(
                df1.Y[k],
                df1.X[k],
                df.Lat[i],
                df.Long[i]
            )
        )
        
        
        k += 1
    
    n = 0
    number_near = 0
    
    
    while n < len(array):
        
        if (array[n]*100000) < 3000:
            number_near += 1
            n +=1
        else:
            n += 1
    
    
    a = np.array(array)
    
    df['Charging_Stations_distance_25'][i] = np.percentile(a, 25)*100000
    df['Charging_Stations_distance_min'][i] = a.min()*100000
    df['Charging_Stations_number_near'][i] = number_near
    
    i += 1
# Out:
# /home/olexandr/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/olexandr/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/olexandr/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 DAY_OF_WEEK  DISTRICT  HOUR        Lat       Long  \
# 0           0             0      Sunday       2.0     6  42.346381 -71.103794
# 1           1             1      Sunday       1.0     6  42.316841 -71.074585
# 2           2             2      Sunday       2.0     6  42.342841 -71.096990
# 3           3             3      Sunday       1.0     6  42.316441 -71.065829
# 4           4             4      Sunday       9.0     7  42.270516 -71.119900
#
#    MONTH     OCCURRED_ON_DATE    OFFENSE_CODE_GROUP  \
# 0      7  2012-07-08 06:00:00  Residential Burglary
# 1      7  2012-07-08 06:03:00    Aggravated Assault
# 2      7  2012-07-08 06:26:00               Robbery
# 3      7  2012-07-08 06:56:00                 Other
# 4      7  2012-07-08 07:15:00               Robbery
#
#                ...                ToDay  DAY  temperatureMin  temperatureMax  \
# 0              ...                    0    8            30.0            45.0
# ...
